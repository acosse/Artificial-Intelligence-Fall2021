# %% [markdown]
# ## <center>NYU CSCI-UA 9472 Artificial Intelligence </center>
#    ### <center> Biology inspired computing </center>
#
#
# <img src="geneticAlgo.jpeg" width=400 height=400>

# %% [markdown]
# <center>This week we will discuss genetic algorithms, genetic programming, ant colonies and other particle optimization approaches </center>

# %% [markdown]
# #### Exercise 1.OneMax
#
# The OneMax problem is a trivial problem often used to illustrate the use of genetic algorithms. In this problem, we evaluate the fitness of a string by the number of 1's contained in that string. I.e for a length $L$ string $\mathbf{a}$, the oneMax function is defined as follows
#
# \begin{align*}
# f(\mathbf{x}) = \sum_{i=1}^L a_i
# \end{align*}
#
# Implement a genetic algorithm that solves the OneMax Problem. Apply your algorithm for various values of the cross-over probability, mutation probability and take $L=20$. Display the evolution of the error as a function of the iterations.

# %%
# put your code here

# %% [markdown]
# #### Exercise 2. Flip flop
#
# Another easy problem that can be used to benchmark genetic algorithms is the flip flop problem. In this problem, we evaluate the fitness of a string by counting the number of bit flips. An optimal string being one with entirely alternating bits. For that problem, compare the efficiency of the simple genetic algorithm with the simple hill climbing and random hill climbing algorithms (hill climbing with non zero probability to select a direction different from the steepest ascent direction)

# %%
# put your code here

# %% [markdown]
# #### Exercise 3. Rastrigin
#
# The Rastrigin function is a non convex function often used to evaluate the performace of optimization algorithms. The expression of the function is given below.
#
# \begin{align*}
# f(\mathbf{x}) = 10n + \sum_{i=1}^n\left((x_i - 1)^2 - 10\cos(2\pi(x_i - 1))\right)
# \end{align*}
#
# for $x_i \in [-5.12, 5.12]$
#
# Compare the performance of the genetic algorithm, evolution and genetic programming approaches on that function by representing the evolution of the distance to the solution as a function of the iterations.

# %%
# put your code here

# %% [markdown]
# #### Exercise 3 (source: Riedmiller, Blum)
#
# Write a genetic algorithm that searches for the shortest route between $N$ cities. Use an encoding method such that the chromosomes consists of lists of integers determining the indices of the cities . Examples of five-city paths starting in city 4 are e.g. $(4,3,1,2,5), (4,1,5,2,3), (4,5,1,2,3)$. The first chromosome thus encodes the path $4\rightarrow 3\rightarrow 1 \rightarrow 2\rightarrow 5\rightarrow 4$. The fitness should be taken as the inverse of the route length (calculated using the ordinary cartesian distance measure, i.e. not the city-block distance measure). The program should always generate synthactically correct routes, i.e. routes in which each city is visited once and only once until, in the final step, the tour ends by a return to the starting city. Specialized operators for crossover and mutation are needed in order to ensure that the paths are syntactically correct.
#
#
# - Define a _mutation_ operator for the TSP that maps valid chromosomes (i.e. paths) onto other valid chromosomes
#
#
# - Define a _crossover_ operator for the TSP that maps valid chromosomes onto other valid chromosomes
#
#
# - Using the specialized crossover and mutation operators, write an Evolutionary Algorithm that solves the Travelling Salesman Problem
#
#
# - Apply your program to the coordinate matrix given below. and plot the resulting graph.

# %%
import numpy as np
import matplotlib.pyplot as plt 

coordinates_1 = np.random.uniform(-10,10,(50,1))
coordinates_2 = np.random.uniform(-10,10,(50,1))

coordinates = np.hstack((coordinates_1, coordinates_2))

plt.scatter(coordinates[:,0], coordinates[:,1])
plt.show()

# %% [markdown]
# #### Exercise 4. CSPs
#
# Constraint satisfaction (CSP) is known to be hard in the general case. For this reason, genetic algorithm can be used to search for a good candidate solutions. Implement a genetic algorithm for the following CSP:
#
# - 8 Queens problem (which consists of placing 8 queens on a chess board in such a way that no queen threatens the others)
#
#
# - Graph coloring problem (which consists in coloring the vertices of a graph in such a way that no two vertices share the same color)
#
# <img src="8queens.png" width=300 height=300>
# (Example of configuration for 3 queens)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import networkx as nx

G = nx.petersen_graph()
plt.figure()
nx.draw(G)

# %% [markdown]
# #### Exercise 5 Prisoner's dilemma (to be added)
